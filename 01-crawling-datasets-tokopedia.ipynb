# %%
# !pip install -qq google-play-scraper
# Out:
#      |████████████████████████████████| 61kB 3.4MB/s
#   Building wheel for google-play-scraper (setup.py) ... done

# %%
# !pip install -qq -U watermark

# %%
# %reload_ext watermark
# %watermark -v -p pandas, seaborn, google_play_scraper
# Out:
# Python implementation: CPython
# Python version       : 3.7.10
# IPython version      : 5.5.0
#
# pandas             : 1.1.5
# seaborn            : 0.11.1
# google_play_scraper: 1.0.0

# %%
from google_play_scraper import Sort, reviews, app

import matplotlib.pyplot as plt
# %matplotlib inline

result, continuation_token = reviews(
    'com.tokopedia.tkpd',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    count=10000, # defaults to 100
)

# If you pass `continuation_token` as an argument to the reviews function at this point,
# it will crawl the items after 3 review items.

result, _ = reviews(
    'com.tokopedia.tkpd',
    continuation_token=continuation_token # defaults to None(load from the beginning)
)

# %%
import json
import seaborn as sns

from pygments import highlight
from pygments.lexers import JsonLexer
from pygments.formatters import TerminalFormatter

# %config InlineBackend.figure_format='retina'

sns.set(style='whitegrid', palette='muted', font_scale=1.2)

# %%
def print_json(json_object):
  json_str = json.dumps(
    json_object, 
    indent=2, 
    sort_keys=True, 
    default=str
  )
  print(highlight(json_str, JsonLexer(), TerminalFormatter()))

# %%
for i in range (5):
  print_json(result[i])
# Out:
# {
#   "at": "2021-07-07 12:37:14",
#   "content": "Alhamdulillah. Saya senang dgn aplikasi ini. Beberapa pesanan selalu sampai. Barang bagus sesuai keterangan . Saya blanja puas dgn sistem COD. Saya keberatan dgn sistem bayar dulu di gerai Alfamart/ selainnya. Karna rumah q jauh. Saya minta untuk saya sistem COD. Bayar setelah barang diterima.\ud83d\ude4f.",
#   "repliedAt": null,
#   "replyContent": null,
#   "reviewCreatedVersion": "3.130",
#   "reviewId": "gp:AOqpTOH-UemyqGel3vso-OmgWESFyt0680itKAF7q5RsFYluiE_Zg9QzAR-ToG1jrVfEQxFQxPk--KaiA62cwaM",
#   "score": 5,
#   "thumbsUpCount": 81,
#   "userImage": "https://play-lh.googleusercontent.com/a/AATXAJwzsmbvRLRYHHNa1XQY-fUUpb1UD5FlbBV0S90=mo",
#   "userName": "Siti Maskurotin"
# }
#
# {
#   "at": "2021-07-08 08:31:52",
#   "content": "Sy belum menggunakan aplikasi toko pedia tapi saya akan memberikan ranting lima...semoga aplikasi ini tidak mengecewakan saya.......!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!\u00a1!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!\u00a1!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!",
#   "repliedAt": null,
#   "replyContent": null,
#   "reviewCreatedVersion": "3.132",
#   "reviewId": "gp:AOqpTOG40DKa8kxHLh42J501xxLiYO3jedOiZryQJZlrErtmcYxXLj6GLhmJsK3fy87sd58Orh22Rxq021g4y0Y",
#   "score": 5,
#   "thumbsUpCount": 424,
#   "userImage": "https://play-lh.googleusercontent.com/a/AATXAJzZnUHd-xW_8ijBkjXexfUtMj9p6-__HDANp4kb=mo",
#   "userName": "Agustina Dahipo"
# }
#
# {
#   "at": "2021-07-01 15:01:09",
#   "content": "Refundnya gimana ya mbak ? Uang saya tarik lg dr saldo tokopdia ke rekening bank dki , sampe skrg belum sampai ke rekening saya perihal penarikan uangnya , sebesar 1 jt , mohon di proses soal refund (penarikan saldo) ke rekening bank dki saya , masih saja tertahan..",
#   "repliedAt": "2021-07-01 17:48:55",
#   "replyContent": "Hai Kak Arfina, mohon maaf atas ketidaknyamanannya. Silahkan Kakak bisa sampaikan detail kendalanya melalui tkp.me/supportMainapps untuk penanganan lebih lanjut ya -ZS",
#   "reviewCreatedVersion": "3.130",
#   "reviewId": "gp:AOqpTOFtRdwObVrVOfs_u9GGXzcgikDLOSUipYLyf9z3mLcCkWe8n9Bv_zjQeHYeUonZijE8_rOm_QqIYmAZbaE",
#   "score": 1,
#   "thumbsUpCount": 68,
#   "userImage": "https://play-lh.googleusercontent.com/a/AATXAJy6WDt259qNBBuxbfLeimOsvT5pAqXSZzyQ3Zl6=mo",
#   "userName": "Sih Arfina Dewi"
# }
#
# {
#   "at": "2021-07-07 14:12:40",
#   "content": "Kata nya bebas ongkir. Setlah d bayar, transaksi selesai. 10 mnt setelah itu pesanan saya d batalkan. Ada kesalahan dlm penggunaan vocher. Kembaliin duit saya ke rekening. Bukan k saldo tokopedia. Anda batalkan pesanan saya. Tp duit saya anda tahan d aplikasi anda.",
#   "repliedAt": "2021-07-07 15:17:06",
#   "replyContent": "Hai Kak Ustri, mohon maaf atas pengalaman bertransaksinya yang berkendala ya Kak. Kakak boleh melakukan pelaporan melalui link bantuan berikut tkp.me/supportMainapps -AN",
#   "reviewCreatedVersion": "3.130",
#   "reviewId": "gp:AOqpTOH1E8LfHnsUL0M1PDdZXzYPJKx_5tV-PYLMZkOZf_6Niq40O5J9v4guDYt_5xETiRUJEP7USHn51kBC3EA",
#   "score": 1,
#   "thumbsUpCount": 37,
#   "userImage": "https://play-lh.googleusercontent.com/a-/AOh14GgFquvhfiOjV1zMHlxUo9s5o03TIAdl-nH4xyiZlg",
#   "userName": "Ustri Analida"
# }
#
# {
#   "at": "2021-07-08 04:06:42",
#   "content": "Sudah dapat invoice pemebelian, pas beres transaksi tiba-tiba transaksinya gagal. Bukannya kalau sudah dapat invoice artinya barang tersebut sudah di keep sama kita kan? Beda banget sama toko sebelah, kalah sudah dapat kode transaksi berarti itu barang punya kita! Kecewaaaaa.... Jauh-jauh dari kampung ke kota buat bayar hampir 1jam pas beres transaksi gagal.....",
#   "repliedAt": "2021-07-08 04:31:12",
#   "replyContent": "Mohon maaf atas pengalaman bertransaksinya yang berkendala ya Kak. Boleh jelaskan detailnya dan nomor invoicenya dengan isi link berikut ya tkp.me/supportMainapps untuk dilakukan pengecekan lebih lanjut. Ditunggu ya Kak :) -AB",
#   "reviewCreatedVersion": "3.129",
#   "reviewId": "gp:AOqpTOGAKqPC1eJZlgBY1hDHiS5PtKy9zO8ShNN9n6qUhvr9hP7B_c8QxOC-wEPgSDDcw4KyiNKIFl3rFm_2eLI",
#   "score": 1,
#   "thumbsUpCount": 22,
#   "userImage": "https://play-lh.googleusercontent.com/a/AATXAJz9WCT7NNRJ3NEmsUTS_y1FQg3VKCrmpJQdGwCn=mo",
#   "userName": "Nunung Nuraenah"
# }

# %%
len(result)
# Out:
# 10000

# %%
import pandas as pd
app_reviews_df = pd.DataFrame(result)
app_reviews_df.to_csv('reviews-tokopedia.csv', index=None, header=True)
